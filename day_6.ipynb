# %%
text = 'hello'
[text[i:] for i in range(3)]
# Out:
# ['hello', 'ello', 'llo']

# %%
list(zip(*['hello', 'ello', 'llo']))
# Out:
# [('h', 'e', 'l'), ('e', 'l', 'l'), ('l', 'l', 'o')]

# %%
list(zip(*[text[i:] for i in range(3)]))
# Out:
# [('h', 'e', 'l'), ('e', 'l', 'l'), ('l', 'l', 'o')]

# %%
n = int(input())
text = input()
words = text.split()
if len(words) < n : 
    print('wrong')
else:
    n_gram = zip(*[words[i:] for i in range(n)])
# Out:
# wrong

# %% [markdown]
# # 29. 출력 함수 만들기

# %%
def hello():
    print('Hello, world!')

# %%
hello() #함수 호출
# Out:
# Hello, world!

# %% [markdown]
# *내용이 없는 함수 만들 땐 코드에 pass 입력

# %% [markdown]
# 매개변수(parameter): 함수에서 값을 받으려면 ()안에 변수 이름 지정.이 변수를 매개변수라 함. <br>
# 인수(argument) : 함수 호출할 때 넣는 값

# %%
def add(a,b):
    """ 독스트링 : 함수에 대한 설명을 넣는 것"""
    print(a+b)

# %%
add(10, 20)
# Out:
# 30

# %% [markdown]
# - 반환값만 있는 함수

# %%
def one() :    
    return 1

# %%
def add_sub(a,b):
    return a+b, a-b

# %%
x,y = add_sub(10, 20)
print(x,y)
# Out:
# 30 -10

# %%
x= add_sub(10, 20)
x   #튜플 반환됨
# Out:
# (30, -10)

# %% [markdown]
# 프레임: 메모리에서 함수와 함수에 속한 변수가 저장되는 독립적인 공간 <br>
# 전역 프레임 : 파이썬 스크립트 전체에서 접근 가능한 프레임

# %% [markdown]
# -함수는 스택(stack) 방식으로 호출됨 <br>
# -함수를 호출하면 스택의 아래쪽 방향으로 함수가 추가되고 함수가 끝나면 위쪽 방향으로 사라짐 <br>
# -프레임은 스택 안에 있어서 각 프레임을 스택 프레임이라고 부름
# -전역 프레임은 스크립트 파일의 실행이 끝나면 사라짐 <br>

# %%
x= 10
y = 3
def get_quotient_remainder(a,b):
    return a//b, a%b
quotient, remainder = get_quotient_remainder(x, y)
print('몫: {0}, 나머지: {1}'.format(quotient, remainder))
# Out:
# 몫: 3, 나머지: 1

# %% [markdown]
# *format() : 문자열의 {}자리에 값을 순서대로 넣어 출력하는 문자열 포매팅 함수

# %%
x,y = map(int,input().split())
def calc(a,b):
    return a+b, a-b, a*b, a/b
a, s, m, d = calc(x, y)
print('덧셈: {0}, 뺄셈: {1}, 곱셈: {2}, 나눗셈: {3}'.format(a, s, m, d))
# Out:
# 덧셈: 30, 뺄셈: -10, 곱셈: 200, 나눗셈: 0.5

# %%
x = [10, 20, 30]
print(*x)  #리스트 또는 튜플 앞에 *(애스터리스크)를 붙여서 함수에 넣어주기
# Out:
# 10 20 30

# %% [markdown]
# # 30. 위치 인수와 키워드 인수
#
# - 가변 인수 : 인수의 개수가 정해지지 않음 <br>
#     가변 인수 함수 - 매개변수 앞에 * 붙여서 만듬

# %% [markdown]
# -매개변수 관례쩍으로 arguments 줄여서 args로 사용

# %%
def print_numbers(*args):   
    for arg in args:
        print(arg)

# %%
print_numbers(10, 20)
# Out:
# 10
# 20

# %% [markdown]
# - 고정 인수 & 가변 인수 함꼐 사용하기

# %%
def print_numbers(a, *args):  #*args가 고정 매개변수보다 앞쪽에 오면 안됨
    print()
    print(args)

# %% [markdown]
# 키워드 인수(keyword argument) : 인수에 이름(키워드)을 붙이는 기능인데 키워드=값 형식으로 사용
# * print()에서 사용했던 sep, end도 키워드 인수

# %%
def personal_info(name, age, address):
    print('이름: ', name)
    print('나이: ', age)
    print('주소: ', address)

# %%
personal_info(name='홍길동', age=30, address='서울시 용산구 이촌동')
# Out:
# 이름:  홍길동
# 나이:  30
# 주소:  서울시 용산구 이촌동

# %% [markdown]
# 딕셔너리 언패킹 : 딕셔너리 사용해 키워드 인수로 값을 넣는 것 <br>
# 함수(**딕셔너리) <br>
# *이때 딕셔너리의 키는 문자열 형태 <br>
# *를 한번만 사용하면 키가 출력됨

# %%
x = {'name': '홍길동', 'age': 30, 'address': '서울시 용산구 이촌동'}
personal_info(**x)
# Out:
# 이름:  홍길동
# 나이:  30
# 주소:  서울시 용산구 이촌동

# %% [markdown]
# - 키워드 인수 사용하는 가변 인수 함수

# %%
def personal_info(**kwargs): #매개 변수 이릉은 관례쩍으로 keyword arguments (kargs)
    for kw,arg in kwargs.items():
        print(kw,':', arg, sep='')

# %%
personal_info(name='홍길동', age=30, address='서울시 용산구 이촌동')
# Out:
# name:홍길동
# age:30
# address:서울시 용산구 이촌동

# %%
def personal_info(name, age, address='비공개'): #매개변수의 초기값 설정 
    print('이름: ', name)
    print('나이: ', age)
    print('주소: ', address)

# %%
 personal_info('홍길동', 30) #address 부분 비워놓고 호출 가능
# Out:
# 이름:  홍길동
# 나이:  30
# 주소:  비공개

# %% [markdown]
# *를 리스트에 사용하고, **를 딕셔너리에 사용

# %%
korean, english, mathematics, science = 100, 86, 81, 91
def get_max_score(*args):
    return max(args)
    
max_score = get_max_score(korean, english, mathematics, science)
print('높은 점수:', max_score)
 
max_score = get_max_score(english, science)
print('높은 점수:', max_score)
# Out:
# 높은 점수: 100
# 높은 점수: 91

# %%
korean, english, mathematics, science = map(int, input().split())
def get_min_max_score(*args):
     return min(args),  max(args)
def get_average(**kwargs):
         return sum(kwargs.values())/len(kwargs)
min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english,
                            mathematics=mathematics, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
      .format(min_score, max_score, average_score))
 
min_score, max_score = get_min_max_score(english, science)
average_score = get_average(english=english, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
      .format(min_score, max_score, average_score))
# Out:
# 낮은 점수: 76.00, 높은 점수: 90.00, 평균 점수: 84.00
# 낮은 점수: 83.00, 높은 점수: 87.00, 평균 점수: 85.00

# %% [markdown]
# # 31. 재귀호출 사용
# - 재귀호출(recursive caLL) : 함수 안에서 함수 자기자신을 호출하는 방식 <br>
#     반드시 종료 조건 만들어줘야 함

# %%
def hello(count):
    if count ==0:
        return
    print('Hello, world!', count)
    count-=1
    hello(count)
    
hello(5)
# Out:
# Hello, world! 5
# Hello, world! 4
# Hello, world! 3
# Hello, world! 2
# Hello, world! 1

# %%
def factorial(n):
    if n ==1:
        return 1
    return n * factorial(n-1)
print(factorial(5))
# Out:
# 120

# %% [markdown]
# - 재귀호출로 회문 판별

# %%
def is_palindrome(word):
    if len(word) < 2:
        return True
    if word[0] != word[-1]:
        return False
    return is_palindrome(word[1:-1])
print(is_palindrome('hello'))
print(is_palindrome('level'))
# Out:
# False
# True

# %%
def fib(n) :
    if n==0:
        return 0
    elif n==1:
        return 1
    
    else:
    
        return fib(n-1)+fib(n-2)

n = int(input()) #피보나치 수열 
print(fib(n))
# Out:
# 55

# %% [markdown]
# # 32. 람다 표현식
# : 식 형태로 되어 있음. 다른 함수의 인수로 넣을 때 주로 사용
#
# - 형식 <br>
# lambda 매개변수들 : 식
# - 익명 함수 생성함
# - 매개변수, 연산자, 값 등을 조합한 식으로 반환값을 만드는 방식

# %%
plus_ten = lambda x : x+10 # 매개변수 x 하나를 받고, x에 10 더해서 반환

# %%
plus_ten(1)
# Out:
# 11

# %% [markdown]
# - (lambda 매개변수들 : 식)(인수들)

# %%
(lambda x : x+10)(1)
# Out:
# 11

# %% [markdown]
# * 람다 표현식 안에서는 새 변수 생성 불가. --> 반환값 부분은 변수 없이 식 한 줄로 표현할 수 있어야 함

# %%
def plus_ten(x):
    return x + 10

list(map(plus_ten, [1,2,3]))

# %%
list(map(lambda x:x+10,[1,2,3]))
# Out:
# [11, 12, 13]
